# %%
from scipy.fftpack import fft
import numpy as np
import matplotlib.pyplot as plt
xval = np.linspace(-10, 10, 100)
yval = np.exp(-np.abs(xval)**2) #np.sin(xval) + 2* np.sin(9*xval)

plt.plot(xval, yval)
fyval = fft(yval)
plt.plot(xval, np.abs(fyval)/10)
